# %% [markdown]
# # Research Proposal – Team “Error not found” aka Group 19
#
# **Members:**
# - Paul Kloos - 6305245
# - Mega Pradipta - 6068308
# - Bryan Inggas - 5286654
# - Kai Müller - 6306101
# - Stefan Huber – 6306861
#
# # Research Objective:
#
# **Exploratory Analysis of Influencing Factors During the Climb Phase of Selected Airbus Aircraft**
#
# Sub-Research Questions (Sub-RQs):
# - How does velocity change over time during the climb phase?
# - How does altitude change over time during the climb phase?
# - How does climb rate change over time during the climb phase?
# - What factors contribute to deviations from the defined optimal climb rate?
#
# Each of these analyses will be conducted individually for selected Airbus models (A319, A320, A321, A330-200) to identify and showcase the differences in their climb performance characteristics.
#
# # Data:
#
# The dataset for this analysis will be sourced from the OpenSky Network's publicly available dataset on climbing aircraft. Specifically, the validated files for the Airbus A319, A320, A321, and A330-200 will be used for analysis. The dataset contains training, validation, and testing files, and for this study, only the validation files will be selected to ensure unbiased results.
#
# **Data source URL:**
#
# *https://opensky-network.org/datasets/publication-data/climbing-aircraft-dataset/trajs/*
#
# **Time Scale:**
#
# The analysis will focus on data from the year 2017.
#
# **Spatial Scale:**
#
# The dataset initially includes global coverage, but it is further filtered through our data pipeline to include only flights from the city of Paris, which has the most flight data available and is being used by four of the aircraft we are focusing on.
#
# **Visualization:**
#
# Using 2D and if it is contributing also 3D graphs. The main plots used are line plots, scatter plots and correlation matrix.

# %% [markdown]
# # Data Pipeline
#
# The datafile used for this analysis contains four different sets:
#
# 1. **Climbing Dataset for Aircraft Model A319**
#    - This dataset includes climbing flight data specific to the Aircraft Model A319.
#
# 2. **Climbing Dataset for Aircraft Model A320**
#    - This dataset includes climbing flight data specific to the Aircraft Model A320.
#
# 3. **Climbing Dataset for Aircraft Model A321**
#    - This dataset includes climbing flight data specific to the Aircraft Model A321.
#
# 4. **Climbing Dataset for Aircraft Model A332 (A330-200)**
#    - This dataset includes climbing flight data specific to the Aircraft Model A332, also known as the A330-200.
#
# The dataset is then analyzed to assess its content and the description of each data item available.
#
# ## Data Formatting and Filtering
#
# 1. All data are in `csv.xz` format and will be loaded and converted to pickle files to be processed more efficiently.
#
# 2. We identify and clean all the irrelevant data out of the dataset. Furthermore, by utilizing the latitude and longitude values, we precisely isolate and retain only the flight data to the area surrounding Paris. This targeted approach ensures that our analysis is specifically concentrated on flights in their climbing phase around the city of Paris.
#
# 3. After conversion, the data will be processed into dataframes for further analysis.further analysis.roup.

# %%
'Insert Code for preparation data here'
# Out:
# 'Insert Code for preparation data processing here'

# %%
'figure of map range of Paris'
# Out:
# 'figure of map range of Paris'

# %% [markdown]
# ## Processing the data
# **1.** Creating the groups which indicated seperate flight activity: This is achieved by grouping the data set by unique segment number.
#
# **2.** We also look at each data column that can answer our sub-research question, which is:
# - How does velocity change over time during the climb phase?
# - How does altitude change over time during the climb phase?
#
# **3.** Next, these data (velocity and altitude) will be plotted over its timestep to get the line graphics per flight activities of each aircraft.

# %%
'Insert Code for data processing (plotting velocity and altitude over time) here'
# Out:
# 'Insert Code for data processing (plotting velocity and altitude over time) here'

# %% [markdown]
# ## Q1: Velocity change over time during climb phase
#
# For the first sub-research question, we want to look at the velocity change over time during the climb phase for each aircraft model (A319, A320, A321, and A332). It is interesting to analyze how the velocity changes over time during the climb phase and what kind of patterns are visible for this.
#
# Since the data used for this research contained multiple flights/experiments for each aircraft model, the average and the standard deviation from the multiple flight experiments are used to visualize the values for the velocity over time. The average (mean) is displayed by the clearly visible lines and the standard deviation is indicated by the shadows around this average (visible lines). Here, the time step is from 0 until 1800 seconds.

# %% [markdown]
# ![Velocity%20vs%20Time.png](attachment:Velocity%20vs%20Time.png)

# %% [markdown]
# From the figure above, it can be seen that for every aircraft model it has more or less the same pattern in the beginning (until timestep 500) and after that it starts to disperse for each aircraft model. In the beginning, the velocity of every model starts to increase linearly (until timestep 150), then it still increases but with a less steep slope (until timestep 250). After this timestep, the velocity again increases more steeply until it reaches more or less the velocity of 200 m/s and after that the velocity still increases slowly until it reaches the velocity of around 250 m/s and becomes steady at this point.
#
# For the comparison between the aircraft models, if we look from the timestep 625 onwards or from the velocity 225 m/s onwards, it can be seen that the A332 model has the highest average velocity among the other models. At a certain timestep, it even reaches more than 250 m/s. There is certainly a gap of difference in average velocity between the A332 model and the other models. On the other hand, the A319 model has the lowest average velocity compared to other models, even though there is not much a different between the A319 model with the A320/A321 model. One possible reasoning for this is that A319 model is mostly used for short-term flights, hence it does not really need to have the "higher" velocity in order to cut the travel time. Meanwhile for A332 model, it is mostly used for long-haul flights, hence having the highest velocity in the engine might be beneficial to cut the travel time during the flight. Lastly, for the A320 and A321 models, they both have more or less the same average velocity throughout the time. If we look closely to the line plots of the A319 and A321 model (blue and green), it seems that there is a jump at the end of their time step. This could be due to the outliers in the data or the data for these particular timesteps is less compared to the previous timesteps.

# %% [markdown]
# In addition to that, it might also be interesting to see how the velocity behaves over the different altitude during the climb phase. The characteristics of the plot are the same as the previous one, however now the altitude is plotted on the x-axes.

# %% [markdown]
# ![Velocity%20vs%20Altitude.png](attachment:Velocity%20vs%20Altitude.png)

# %% [markdown]
# The average velocity, in the graph presented above, behaves almost the same with the one presented against the timestep, however it looks a bit less subtle. The average velocity pattern behaves (exactly) the same as before, where in the beginning for every aircraft model, the average velocity starts to increase steeply until it reaches around 1800 meters of altitude. After that, it still increases however with a less steep slope until it reaches the altitude of a bit more than 3000 meters at the average velocity of 150 m/s. Then, it increases again more steeply until the average velocity almost reaches 200 m/s at the altitude of almost 4000 meters. After this altitude and onwards, the average velocity still increases slowly and it becomes steady around 250 m/s and at the altitude range of 10000 - 12000 meters.

# %% [markdown]
# For every aircraft models, the average velocity are the same more or less from altitude 0 meter until 3800 meters (almost 4000 meters). However, just right before the altitude of 4000 meters, the A319 model has the lowest average velocity compared to others. This holds until it reaches the altitude of 11000 meters. Meanwhile for the other three models (A320, A321, and A332), the average velocity are the same until it reaches 8000 meters of altitude where the A332 model has a larger increase in average velocity which makes it having the largest average velocity from this altitude and onwards. It even exceeds the average velocity of 250 m/s from the altitude range of 9000 meters to 12000 meters. Lastly, at the altitude around 11000 meters, the average velocity is roundly the same for the A319, A320, and A321 models, in which it reaches almost 250 m/s.

# %% [markdown]
# ## Q2: Altitude change over time during climb phase
#
# For the second sub-research question, it would also be interesting to analyze how the altitude of the different aircraft models (A319, A320, A321, and A332) behaves over time during their climb phase. How high these different aircraft models reaches a certain altitude over/at a specific time step will be plotted.

# %% [markdown]
# ![Altitude%20vs%20Time.png](attachment:Altitude%20vs%20Time.png)

# %% [markdown]
# The average altitude over the time plot shows that the average altitude for every aircraft model increases smoothly throughout the time. The dispersion in the increase of the average altitude can already be seen from the timestep around 300 where the A319 model's average altitude starts to increase way more higher and has a bit more steeper slope compared to other models. Hence, from that timestep onwards, the A319 model has already a higher altitude compared to others by looking at that particular timestep. In the end, it reaches 12000 meters of altitude in average way more faster/earlier compared to other models, at the timestep of 1500 seconds. Meanwhile for other models (A320, A321, and A332), the increase in average altitude is more or less the same throughout the time. Unless if we look around the timestep 1000, here the average altitude for the A332 model is higher compared to the A320 and A321 model. However, after this period of timestep, it becomes similar again in the average altitude. Reaching the end of the timestep (around 1500 seconds), it seems that the A321 model has a decrease in average altitude for whatever reason. All in all, for these three aircraft models (A320, A321, and A332), they have a range of 10000 - 11000 meters for its average altitude at this particular timestep of 1500 seconds or 25 minutes.

# %% [markdown]
# One possible reason why the A319 model has the highest altitude among the other models at a particular timestep is that it could be that the A319 model should already be as high as possile during the climb phase since it is only doing a short period of flight. Hence, it has to be as high as possible in altitude in order to avoid traffic, which occurs in the air, as soon as possible.

# %% [markdown]
# ## Calculating the Climb Rate
#
# **1.** The climb rate is a measurement of how quickly an aircraft can increase its altitude. It is usually expressed in feet per minute (fpm) or meters per second (m/s). This parameter is crucial in aviation, affecting the efficiency, safety, and performance of flight operations.
#
# **2.** The climb rate can be calculated using the formula:
#    $$\text{Climb Rate} = \frac{\Delta \text{Altitude}}{\Delta \text{Time}}$$
#    Where:
#    - $\Delta \text{Altitude}$ is the change in altitude.
#    - $\Delta \text{Time}$ is the time it takes for that change.
#
# **3.** Next, this calculation will be derived from the `baroaltitude` and `timestep` columns in our data.

# %%
'Insert Code for Climb Rate data processing here'

# %% [markdown]
# ## Factors Contributing to Deviation of Climb Rate from Its Optimal Range
#
# **1.** The climb rate of each aircraft model has its own optimal range.
#
# **2.** We can determine when each aircraft's climb rate deviates from its optimal range (entering and exiting).
#
# **3.** A correlation matrix is used to see the impact of each parameter in relation to each other and with the climb rate of each aircraft.craft.

# %%
'Insert Code for Adding enter-exit marker for climb rate'

# %%
'Insert Code for the correlation matrix'
